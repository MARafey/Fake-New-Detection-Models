# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
import re
import string

# %%
data = pd.read_csv('train.csv')
data.isnull().sum()
df = data.dropna()
df.isnull().sum()
# sort the train data
df = df.sort_values(by='label')

# split the data into data sets one where the label entry is 1 and the other when its 0
true = df[df['label'] == 1]
fake = df[df['label'] == 0]

# %%
fake.head()
# Out:
#           id                                              title  \
# 10422  10422  Early French Presidential Polls Show Macron in...
# 16863  16863  Pope Greets Schwarzenegger, Possible Ambassado...
# 9199    9199  Tips for Shoring Up a Fragile Thanksgiving - T...
# 9201    9201  Trump Strategist Stephen Bannon Says Media Sho...
# 9202    9202  VIDEO: Sen. Kamala Harris Uses the F-Word at P...
#
#                                 author  \
# 10422                  Chris Tomlinson
# 16863        Thomas D. Williams, Ph.D.
# 9199   Wesley Morris and Jenna Wortham
# 9201               Michael M. Grynbaum
# 9202               Katherine Rodriguez
#
#                                                     text  label
# 10422  Polls released since the first round of the Fr...      0
# 16863  Pope Francis greeted former California governo...      0
# 9199   Is it possible to break Thanksgiving? And if s...      0
# 9201   WASHINGTON  —   Just days after President Trum...      0
# 9202   Sen. Kamala Harris ( ) dropped the “ ” at a pu...      0

# %%
true.head()
# Out:
#           id                                              title  \
# 20749  20749  Realities Faced by Black Canadians are a Natio...
# 20118  20118                                     The Trump Ploy
# 15309  15309  ERICA GARNER BLASTS CLINTON CAMPAIGN OVER DISC...
# 15349  15349  Mike Pence To Head To Irish Maternity Hospital...
# 15331  15331  FBI PANIC! Hillary LIES In First Press Confere...
#
#               author                                               text  label
# 20749      Anonymous  Tweet Widget by Robyn Maynard \nCanada, includ...      1
# 20118      Linh Dinh  Michele Paccione / Shutterstock.com \nUniversa...      1
# 15309     Iron Sheik  Home › POLITICS | US NEWS › ERICA GARNER BLAST...      1
# 15349  Gerry McBride  0 Add Comment \nTHE unapologetically pro-life ...      1
# 15331            DSG  Videos Hillary Clinton FBI PANIC! Hillary LIES...      1

# %%
fake['class']=0
true['class']=1
# Out:
# <ipython-input-9-2359b8fe78ed>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fake['class']=0
# <ipython-input-9-2359b8fe78ed>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   true['class']=1

# %%
fake.shape, true.shape
# Out:
# ((10361, 6), (7924, 6))

# %%
fake.drop(fake.tail(2064).index, inplace=True)
# Out:
# <ipython-input-11-f17651648c9a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fake.drop(fake.tail(2064).index, inplace=True)

# %%
fake.shape, true.shape
# Out:
# ((8297, 6), (7924, 6))

# %%
fake_manual_testing.loc[:, 'class'] = 0
true_manual_testing.loc[:, 'class'] = 1

# %%
fake_manual_testing.head(10)
# Out:
#           id                                              title  \
# 368      368  Your Monday Evening Briefing: Brexit, Abortion...
# 5442    5442  A Ranger, a Field of Wildflowers and the Retel...
# 18116  18116  Thousands Expected to Rally for Expanded Schoo...
# 358      358  Ann Coulter Unloads on Paul Ryan’s ’Deeply Unp...
# 6288    6288  Just 11 Miles Off Coast, California’s Galápago...
# 18437  18437  Letters From Jacqueline Kennedy to the Man She...
# 5482    5482  Police Helicopter Deployed, Karaoke Machine Co...
# 5481    5481  Scenes From Hurricane Matthew’s Capricious Pat...
# 84        84  Trump’s Immigration Policies Explained - The N...
# 18438  18438  Iran Races to Clinch Oil Deals Before Donald T...
#
#                                                   author  \
# 368            Jonah Engel Bromwich and Sandra Stevenson
# 5442                                           Dan Barry
# 18116                                       Merrill Hope
# 358                                         Katie McHugh
# 6288                                      Lucas Peterson
# 18437                                    Steven Erlanger
# 5482                                      Oliver JJ Lane

# 20799  20799                          What Keeps the F-35 Alive
#
#                                 author  \
# 10422                  Chris Tomlinson
# 16863        Thomas D. Williams, Ph.D.
# 9199   Wesley Morris and Jenna Wortham
# 9201               Michael M. Grynbaum
# 9202               Katherine Rodriguez
# ...                                ...
# 9739                         Profusion
# 9740           Terresa Monroe-Hamilton
# 9741                          EdJenner
# 9731                            hqanon
# 20799                    David Swanson
#
#                                                     text  label  class
# 10422  Polls released since the first round of the Fr...      0      0
# 16863  Pope Francis greeted former California governo...      0      0
# 9199   Is it possible to break Thanksgiving? And if s...      0      0
# 9201   WASHINGTON  —   Just days after President Trum...      0      0
# 9202   Sen. Kamala Harris ( ) dropped the “ ” at a pu...      0      0
# ...                                                  ...    ...    ...
# 9739   link She and Nutinbutayahoo have been wanting ...      1      1
# 9740     NORTH CAROLINA: Top Democratic Donor – Black...      1      1
# 9741   Go to Article \nPolitical activist and Hillary...      1      1
# 9731   On September 5, 2006, Eli Chomsky was an edito...      1      1
# 20799    David Swanson is an author, activist, journa...      1      1
#
# [16221 rows x 6 columns]

# %%
df.columns
# Out:
# Index(['id', 'title', 'author', 'text', 'label', 'class'], dtype='object')

# %%
df = df.drop(['id','title', 'author'], axis =1)

# %%
df.tail()
# Out:
#                                                     text  label  class
# 9739   link She and Nutinbutayahoo have been wanting ...      1      1
# 9740     NORTH CAROLINA: Top Democratic Donor – Black...      1      1
# 9741   Go to Article \nPolitical activist and Hillary...      1      1
# 9731   On September 5, 2006, Eli Chomsky was an edito...      1      1
# 20799    David Swanson is an author, activist, journa...      1      1

# %%
df = df.sample(frac =1)

# %%
df.head()
# Out:
#                                                     text  label  class
# 11107  If Donald J. Trump wins the White House and pr...      0      0
# 9644   Massive Spherical Space Object Disturbed NASA’...      1      1
# 1754   Sunday on CNN’s “GPS,” while discussing the ne...      0      0
# 17049  How to Survive a Nuclear Fallout Ad 728×90 – H...      1      1
# 11975  source Add To The Conversation Using Facebook ...      1      1

# %%
df.reset_index(inplace=True)
df.drop(['index'], axis=1, inplace = True)

# %%
df.columns
# Out:
# Index(['text', 'label', 'class'], dtype='object')

# %%
df.isnull().sum()
# Out:
# text     0
# label    0
# class    0
# dtype: int64

# %%
df.head()
# Out:
#                                                 text  label  class
# 0  If Donald J. Trump wins the White House and pr...      0      0
# 1  Massive Spherical Space Object Disturbed NASA’...      1      1
# 2  Sunday on CNN’s “GPS,” while discussing the ne...      0      0
# 3  How to Survive a Nuclear Fallout Ad 728×90 – H...      1      1
# 4  source Add To The Conversation Using Facebook ...      1      1

# %%
def wordopt(text):
    text = text.lower()
    text = re.sub(r'\[.*?\]', '', text)
    text = re.sub(r"https?://\S+|www\.\S+", " ", text)
    text = re.sub(r'<.*?>+', '', text)
    text = re.sub(r'[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub(r'\n', '', text)
    text = re.sub(r'\w*\d\w*', '', text)
    return text

# %%
df['text'] = df['text'].apply(wordopt)

# %%
x=df['text']
y=df['class']

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.3)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorization = TfidfVectorizer()
xy_train = vectorization.fit_transform(x_train)
xy_test = vectorization.transform(x_test)

# %%
from sklearn.tree import DecisionTreeClassifier

DT = DecisionTreeClassifier()
DT.fit(xy_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
pred_dt = DT.predict(xy_test)

# %%
DT.score(xy_test, y_test)
import pickle
pickle.dump(DT, open('/content/DecisionTreeModel.pkl','wb'))

# %%
print(classification_report(y_test, pred_lr))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-b2d4929b41d2> in <cell line: 1>()
# ----> 1 print(classification_report(y_test, pred_lr))
#
# NameError: name 'pred_lr' is not defined

# %%
def output_label(n):
    if n==0:
        return "Fake News"
    elif n==1:
        return "Not a Fake News"

def manual_testing(news):
    testing_news = {"text": [news]}
    new_def_test = pd.DataFrame(testing_news)
    new_def_test["text"] = new_def_test["text"].apply(wordopt)
    new_x_test = new_def_test['text']
    new_xy_test = vectorization.transform(new_x_test)
    pred_LR = LR.predict(new_xy_test)
    pred_DT = DT.predict(new_xy_test)

    print("LR Prediction:", output_label(pred_LR[0]))
    print("DT Prediction:", output_label(pred_DT[0]))

    return output_label(pred_LR[0]), output_label(pred_DT[0])

# %%
news_input = str(input("Enter the news string: "))
manual_testing(news_input)
# Out:
# Enter the news string: Today is my death day
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-80177af62b3e> in <cell line: 2>()
#       1 news_input = str(input("Enter the news string: "))
# ----> 2 manual_testing(news_input)
#
# <ipython-input-40-86308de65375> in manual_testing(news)
#      11     new_x_test = new_def_test['text']
#      12     new_xy_test = vectorization.transform(new_x_test)
# ---> 13     pred_LR = LR.predict(new_xy_test)
#      14     pred_DT = DT.predict(new_xy_test)
#      15
#
# NameError: name 'LR' is not defined
